# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DF = pd.read_csv("train.csv")
print(DF.shape)
DF[:10]
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
Y = np.array(DF["Survived"])
X = pd.DataFrame([DF["Sex"], DF["Age"], DF["Fare"]]).T

# %%
plt.hist(DF["Pclass"])
plt.xlabel("Class")
plt.ylabel("Frequency")
plt.grid();

# %%
plt.scatter(DF["Pclass"], DF["Fare"])
plt.grid()

# %% [markdown]
# ## Isolating lastnames and titles

# %%
names = []
for x in np.array(DF["Name"]):
    tokens = x.split('. ', maxsplit = 1)
    names.append(tokens)
namedata = pd.DataFrame(names, columns = ["Surname/title", "First/Middle"])

# %%
namedata
# Out:
#            Surname/title                                 First/Middle
# 0             Braund, Mr                                  Owen Harris
# 1           Cumings, Mrs        John Bradley (Florence Briggs Thayer)
# 2        Heikkinen, Miss                                        Laina
# 3          Futrelle, Mrs                Jacques Heath (Lily May Peel)
# 4              Allen, Mr                                William Henry
# 5              Moran, Mr                                        James
# 6           McCarthy, Mr                                    Timothy J
# 7        Palsson, Master                                Gosta Leonard
# 8           Johnson, Mrs          Oscar W (Elisabeth Vilhelmina Berg)
# 9            Nasser, Mrs                       Nicholas (Adele Achem)
# 10       Sandstrom, Miss                               Marguerite Rut
# 11         Bonnell, Miss                                    Elizabeth
# ...

# %%
surnamesandtitles = pd.DataFrame(namedata["Surname/title"])
names2 = []
for x in np.array(surnamesandtitles["Surname/title"]):
    tokens = x.split(', ', maxsplit = 1)
    names2.append(tokens)
names2 = pd.DataFrame(names2, columns = ["Surname", "Title"])
np.unique(names2["Title"])
DF = pd.concat([DF, names2], axis = 1)

# %%
DF
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ## Some broad data visualization

# %%
ismale = DF["Sex"]=="male"
males = DF[ismale]
females = DF[ismale == False]

# %%
plt.hist(males["Survived"]);
print("Male survival rate: ", (len(males[males["Survived"] == 1])/len(males))*100, "%")
# Out:
# Male survival rate:  18.890814558058924 %

# %%
plt.hist(females["Survived"]);
print("Female Survival rate: ",len(females[females["Survived"] == 1])/len(DF)*100, "%" )
# Out:
# Female Survival rate:  26.15039281705948 %

# %%
plt.hist(DF[DF["Title"]=="Master"]["Survived"])
plt.title("Survival of Young Men (< 12yo)")
plt.xlabel("Survived")
plt.ylabel("Frequency")
plt.grid();

# %%
mrs = DF[DF["Title"]=="Mrs"]
plt.hist(mrs["Survived"])
plt.title("Survival of Married Women")
plt.xlabel("Survival")
plt.ylabel("Freq")
plt.grid();

# %%
miss = DF[DF["Title"]=="Miss"]
plt.hist(miss["Survived"])
plt.title("Survival of Unmarried Females")
plt.xlabel("Survival")
plt.ylabel("Freq")
plt.grid();

# %%
Mr = DF[DF["Title"]=="Mr"]
plt.hist(Mr["Survived"])
plt.title("Survival of Men with \"Mr.\" Title")
plt.xlabel("Survival")
plt.ylabel("Freq")
plt.grid();

# %%
firstclass = DF[DF['Pclass']==1]
secondclass = DF[DF['Pclass']==2]
thirdclass = DF[DF['Pclass']==3]

# %%
plt.hist(thirdclass['Fare'], edgecolor = 'k', color = 'pink')
plt.title("Distribution of Ticket Prices for 3rd Class")
plt.xlabel('Fare')
plt.ylabel('Freq')
plt.grid();

# %%
plt.hist(secondclass['Fare'], edgecolor = 'k', color = 'pink')
plt.title("Distribution of Ticket Prices for 2nd Class")
plt.xlabel('Fare')
plt.ylabel('Freq')
plt.grid();

# %%
plt.hist(firstclass['Fare'], edgecolor = 'k', color = 'pink')
plt.title("Distribution of Ticket Prices for 1st Class")
plt.xlabel('Fare')
plt.ylabel('Freq')
plt.grid();

# %%
plt.hist(firstclass['Survived'])
plt.title("Surivival of 1st Class Passengers")
plt.xlabel('1=survived, 0=not')
plt.ylabel('Freq')
plt.grid();

# %%
plt.hist(secondclass['Survived'])
plt.title("Surivival of 2nd Class Passengers")
plt.xlabel('1=survived, 0=not')
plt.ylabel('Freq')
plt.grid();

# %%
plt.hist(thirdclass['Survived'])
plt.title("Surivival of 3rd Class Passengers")
plt.xlabel('1=survived, 0=not')
plt.ylabel('Freq')
plt.grid();

# %%
for x in np.unique(DF["Title"]):
    tokenDF = pd.DataFrame(DF[DF["Title"]==x])
    averageage = np.mean(tokenDF["Age"])
    empties = tokenDF[tokenDF["Age"].isnull()]
    DF[(DF["Title"]==x) & (DF["Age"].isnull())] = DF[(DF["Title"]==x) & (DF["Age"].isnull())].fillna(value = averageage)

# %% [markdown]
# ## Training the model

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import warnings
warnings.filterwarnings("error")

# %%
errs=[]
nsplits=100
skipped=0
X = pd.DataFrame([DF["Sex"], DF["Age"], DF["Pclass"]]).T

# Casting categorical data to numerical categories
X['Sex']= X['Sex'].astype('category')
X['Sex'] = X['Sex'].cat.codes


Y= np.array(DF["Survived"])
for j in range(nsplits):
  try:
    XTRAIN, XTEST, YTRAIN, YTEST=train_test_split(X,Y, test_size = .2)
    LDA = LinearDiscriminantAnalysis(solver = "lsqr", shrinkage = "auto")
    LDA.fit(XTRAIN,YTRAIN)
    YP=LDA.predict(XTEST)
    errs.append(1-accuracy_score(YTEST,YP))
  except UserWarning:
    skipped+=1
    continue
print("LDA mean error=%7.5f std=%7.5f" %(np.mean(errs),np.std(errs)))
print(skipped,"train/test splits had to be skipped because of Normalization Errors")
# Out:
# LDA mean error=0.21318 std=0.03139
# 0 train/test splits had to be skipped because of Normalization Errors

# %%
X
# Out:
#      Sex      Age Pclass
# 0      1       22      3
# 1      0       38      1
# 2      0       26      3
# 3      0       35      1
# 4      1       35      3
# 5      1  32.3681      3
# 6      1       54      1
# 7      1        2      3
# 8      0       27      3
# 9      0       14      2
# 10     0        4      3
# 11     0       58      1
# 12     1       20      3
# 13     1       39      3
# 14     0       14      3
# 15     0       55      2
# 16     1        2      3
# 17     1  32.3681      2
# 18     0       31      3
# 19     0  35.8981      3
# 20     1       35      2
# 21     1       34      2
# 22     0       15      3
# 23     1       28      1
# 24     0        8      3
# 25     0       38      3
# 26     1  32.3681      3
# 27     1       19      1
# 28     0   21.774      3
# 29     1  32.3681      3
# ..   ...      ...    ...
# 861    1       21      2
# 862    0       48      1
# 863    0   21.774      3
# 864    1       24      2
# 865    0       42      2
# ...

# %% [markdown]
# ## Prediction to upload

# %%
testDF = pd.read_csv("test.csv")

# %% [markdown]
# ## Cleaning test data

# %%
testnames = []
for x in np.array(testDF["Name"]):
    tokens = x.split('. ', maxsplit = 1)
    testnames.append(tokens)
testnamedata = pd.DataFrame(testnames, columns = ["Surname/title", "First/Middle"])

testsurnamesandtitles = pd.DataFrame(testnamedata["Surname/title"])
testnames2 = []
for x in np.array(testsurnamesandtitles["Surname/title"]):
    tokens = x.split(', ', maxsplit = 1)
    testnames2.append(tokens)
testnames2 = pd.DataFrame(testnames2, columns = ["Surname", "Title"])
np.unique(testnames2["Title"])
testDF = pd.concat([testDF, testnames2], axis = 1)

# %%
testDF
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
for x in np.unique(testDF["Title"]):
    tokenDF = pd.DataFrame(testDF[testDF["Title"]==x])
    averageage = np.mean(tokenDF["Age"])
    empties = tokenDF[tokenDF["Age"].isnull()]
    testDF[(testDF["Title"]==x) & (testDF["Age"].isnull())] = testDF[(testDF["Title"]==x) & (testDF["Age"].isnull())].fillna(value = averageage)

# %%
testDF[(testDF["Title"]=="Ms") & (testDF["Age"].isnull())] = testDF[(testDF["Title"]=="Ms") & (testDF["Age"].isnull())].fillna(value = 21.774844)
testDF
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
XT = pd.DataFrame([testDF["Sex"], testDF["Age"], testDF["Pclass"]]).T
XT['Sex']= XT['Sex'].astype('category')
XT['Sex'] = XT['Sex'].cat.codes

XT
# Out:
#      Sex      Age Pclass
# 0      1     34.5      3
# 1      0       47      3
# 2      1       62      2
# 3      1       27      3
# 4      0       22      3
# 5      1       14      3
# 6      0       30      3
# 7      1       26      2
# 8      0       18      3
# 9      1       21      3
# 10     1       32      3
# 11     1       46      1
# 12     0       23      1
# 13     1       63      2
# 14     0       47      1
# 15     0       24      2
# 16     1       35      2
# 17     1       21      3
# 18     0       27      3
# 19     0       45      3
# 20     1       55      1
# 21     1        9      3
# 22     0  38.9032      1
# 23     1       21      1
# 24     0       48      1
# 25     1       50      3
# 26     0       22      1
# 27     1     22.5      3
# 28     1       41      1
# 29     1       32      3
# ..   ...      ...    ...
# 388    1       21      3
# 389    1        6      3
# 390    1       23      1
# 391    0       51      1
# 392    1       13      3
# ...

# %% [markdown]
# ## Prediction

# %%
YT = LDA.predict(XT)

# %%
pass_id = testDF["PassengerId"]
output = pd.DataFrame({"PassengerId":np.array(pass_id),
                  "Survived": YT})
output.to_csv("result.csv", sep =",",index = False)

# %%
output
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         1
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         1
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# ...
